# %%
import pandas as pd
import pickle
from sklearn.ensemble import RandomForestRegressor

# Load
df = pd.read_csv("data/station_hour.csv")

# Basic preprocessing
df['Datetime'] = pd.to_datetime(df['Datetime'])

df['hour'] = df['Datetime'].dt.hour
df['day'] = df['Datetime'].dt.day
df['month'] = df['Datetime'].dt.month

df = df[['AQI', 'hour', 'day', 'month']].dropna()

X = df[['hour', 'day', 'month']]
y = df['AQI']

model = RandomForestRegressor(n_estimators=20, max_depth=10)
model.fit(X, y)

# Save model
with open("model.pkl", "wb") as f:
    pickle.dump(model, f)
# Out:
# C:\Users\sarbo\AppData\Local\Temp\ipykernel_32188\1610749046.py:6: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/station_hour.csv")
